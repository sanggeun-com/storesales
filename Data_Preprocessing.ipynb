# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %%
### 함수 정의 ###

# 수치형 데이터 다운캐스팅(Downcasting)
def downcast(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        dtype_name=df[col].dtype.name
        if dtype_name=='object':
            pass
        elif dtype_name=='bool':
            df[col]=df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round()==df[col]).all():
            df[col]=pd.to_numeric(df[col], downcast='integer')
        else:
            df[col]=pd.to_numeric(df[col], downcast='float')
    end_mem=df.memory_usage().sum() / 1024**2
    
    if verbose:
        print('{:.1f}% 압축됨'.format(100*(start_mem-end_mem)/start_mem))

# train/test 데이터프레임과 stores 데이터프레임을 입력받아 데이터 머지 후, 반환하는 함수
def train_store_mearge(input, stores):
    return pd.merge(input, stores, how='left', on='store_nbr')

# oil 데이터의 빠진 날짜와 dcoilwtico 데이터를 interpolation으로 채운 dataframe을 반환하는 함수
def fill_oil_data(df):
    # date 열을 인덱스로 설정
    df.set_index('date', inplace=True)
    # 전체 날짜 범위를 생성하여 누락된 날짜를 추가 (min에서 max 사이의 모든 날짜)
    df = df.reindex(pd.date_range(start=df.index.min(), end=df.index.max()))
    # price 값을 선형 보간법으로 채우기
    df['dcoilwtico'] = df['dcoilwtico'].interpolate()
    # 인덱스를 다시 date 열로 복원
    df.reset_index(inplace=True)
    df.rename(columns={'index': 'date'}, inplace=True)
    return df

# 날짜와 holiday list를 입력받아, 해당 날짜가 holiday 인지 판별하여 True/False 값 반환하는 함수
def is_holiday(dt, hdts):
    result = dt in hdts.values
    return result

# 날짜를 입력받아 해당 날짜가 workday 인지 weekend인지 판별하고 결과를 'workday' or 'weekend'로 반환하는 함수
def normal_day_type(dt):
    if dt.weekday() >= 5:
        return 'Weekend'
    else:
        return 'Work Day'
    
# 이벤트/Holiday 이름에서 Transfer를 삭제하는 함수
def replace_prefix(value):
    # 접두사가 "Traslado "로 시작하는지 확인
    if value.startswith("Traslado "):
        # 접두사를 빈 문자열로 교체
        return value.replace("Traslado ", "", 1)
    return value
    
# ['date'], ['city'], ['state'] 그리고 df_holiday_events 데이터프레임을 입력받아 date.holiday type을 반환하는 함수
def date_type(dt, city, state, dhe):
    dt_type = ""
    dt_description = ""
    # 입력받은 날짜가 df_holiday_events에 포함되어 있는 경우, lcoal->regional->national holidays 순서로 해당되는 type을 확인
    if is_holiday(dt, dhe['date']):
        holidays = dhe[dhe['date'] == dt]
        for _, holiday in holidays.iterrows():
            # Local인 경우, city 비교
            if holiday['locale'] == 'Local' and city == holiday['locale_name']:
                dt_type = holiday['type']
                dt_description = replace_prefix(holiday['description'])
                break
            elif holiday['locale'] == 'Regional' and state == holiday['locale_name']:
                dt_type = holiday['type']
                dt_description = replace_prefix(holiday['description'])
            elif holiday['locale'] == 'National' and dt_type == "":
                dt_type = holiday['type']
                dt_description = replace_prefix(holiday['description'])
    if dt_type == "":
        dt_type = normal_day_type(dt)
        if dt_type =='Weekend':
            dt_description = "Weekend"
        else:
            dt_description = "Work Day"
    return (dt_type, dt_description)

def pre_proecess(df, df_stores, df_holiday_events, df_oil, purpose='train'):
    # df_oil_filled 데이터의 빠진 날짜 및 dcoilwtico 데이터 채우기
    df_oil_filled = df_oil.copy()
    df_oil_filled = fill_oil_data(df_oil_filled)
    # 데이터의 첫 날 (2013-01-01)의 dcoilwtico 데이터는 누락되어 있으므로, 그 다음날의 dcoilwtico 값과 동일한 것으로 가정
    df_oil_filled.iloc[0, 1] = df_oil_filled.iloc[1, 1]  
    # train 데이터에 dcoilwtico 값 추가
    df_train_stores = train_store_mearge(df, df_stores)

    # 헤더만 쓰기 위해 첫 번째 빈 데이터프레임을 저장
    with open ('temp_data.csv', 'w') as f:
        pd.DataFrame(columns=df_train_stores.columns.tolist()+['date_type']+['date_description']+['year']+['month']+['day']+['weekday']).to_csv(f, index=False)

    # 데이터 프레임을 chunk_size씩 데이터를 확인하면서, holiday_events 데이터를 기준으로 date_type을 확인해서 train 데이터에 추가
    chunk_size = 1000
    end_row = len(df_train_stores)

    for i in range(0, end_row + chunk_size, chunk_size):
        if i > end_row:
            print(f"{idx} rows are porcessed.")
            break
        else:
            chunk = df_train_stores.iloc[i:i + chunk_size].copy()  # i에서 i + chunk_size까지 슬라이싱
            # date_type을 구분
            for idx, row in chunk.iterrows():
                dt_tp, dt_des = date_type(row['date'], row['city'], row['state'], df_holiday_events)
                chunk.at[idx,'date_type']=dt_tp
                chunk.at[idx,'date_description']=dt_des
        # chunk['date']를 year, month, day, weekday로 분리
        chunk['date'] = pd.to_datetime(chunk['date'])
        chunk['year'] = chunk['date'].dt.year
        chunk['month'] = chunk['date'].dt.month
        chunk['day'] = chunk['date'].dt.day
        chunk['weekday'] = chunk['date'].dt.day_name()

        print(f"{i+1} row(s) are porcessed.")
        # 결과를 파일에 추가 모드로 저장
        chunk.to_csv('temp_data.csv', mode='a', header=False, index=False)

    # train data에 stroes 및 date_type 정보가 추가된 데이터를 temp_data 데이터프레임에 임시 저장
    temp_data = pd.read_csv('temp_data.csv', parse_dates =['date'])
    # temp_data에 df_oil_filled 데이터를 기준으로 dcoilwtico 데이터를 추가해서, train_data 데이터 프레임에 저장
    train_data = pd.merge(temp_data, df_oil_filled, how='left', on='date')
    
    # 처리한 데이터를 저장할 csv 파일명을 purpose 기준으로 생성하고, train_data를 해당 csv 파일에 저장
    filename = purpose+".csv"
    train_data.to_csv(filename, index=False)

    print("Data preprocess is completed, and the result is saved to train_data.csv.")
    print(train_data.info())

    # temp_data.csv 파일 삭제
    if os.path.exists('temp_data.csv'):
        os.remove('temp_data.csv')
        print(f"temp_data.csv 파일이 삭제되었습니다.")
    else:
        print(f"temp_data.csv 파일이 존재하지 않습니다.")

    return True

# 모델에 사용할 수 있도록 데이터 변환을 위한 함수 정의

from sklearn.preprocessing import LabelEncoder

def label_encoding(df1,df2,features = ['year', 'month', 'weekday','date_description', 'store_nbr','family', 'city', 'state', 'type', 'cluster']):

    # LabelEncoder 객체 생성
    label_encoder = LabelEncoder()
    
    # 문자열 변수들을 정수로 인코딩
    for ft in features:
        label_encoder.fit(df1[ft])
        df1[ft]=label_encoder.transform(df1[ft])
        df2[ft]=label_encoder.transform(df2[ft])

    return df1, df2

from sklearn.preprocessing import StandardScaler
def scaler_function (df1, df2, features = ['onpromotion','dcoilwtico']):
    # StandardScaler 생성
    scaler = StandardScaler()
    scaler.fit(df1[features])

    # 선택한 열만 표준화
    df1[features] = scaler.transform(df1[features])
    df2[features] = scaler.transform(df2[features])

    # 변환된 데이터를 DataFrame으로 반환
    return df1, df2

# %%
# train, store, holiday_events, oil, test 데이터 로드 / df_test 데이터에 대한 transaction 데이터는 존재하지 않기 때문에 transcation 데이터는 모델 학습에 사용하지 않음
path = 'store-sales-time-series-forecasting/'
df_train = pd.read_csv(path + 'train.csv',parse_dates =['date'])
df_stores = pd.read_csv(path + 'stores.csv')
df_holiday_events = pd.read_csv(path + 'holidays_events.csv',parse_dates =['date'])
df_oil = pd.read_csv(path + 'oil.csv',parse_dates =['date'])
df_test = pd.read_csv(path + 'test.csv',parse_dates =['date'])

# %%
# 원본 데이터 파일을 merge 및 1차 전처리
pre_proecess(df = df_train, df_stores=df_stores, df_holiday_events=df_holiday_events, df_oil=df_oil, purpose='train_w_val')
pre_proecess(df = df_test, df_stores=df_stores, df_holiday_events=df_holiday_events, df_oil=df_oil, purpose='test')
# Out:
# 1 row(s) are porcessed.
# 1001 row(s) are porcessed.
# 2001 row(s) are porcessed.
# 3001 row(s) are porcessed.
# 4001 row(s) are porcessed.
# 5001 row(s) are porcessed.
# 6001 row(s) are porcessed.
# 7001 row(s) are porcessed.
# 8001 row(s) are porcessed.
# 9001 row(s) are porcessed.
# 10001 row(s) are porcessed.
# 11001 row(s) are porcessed.
# 12001 row(s) are porcessed.
# 13001 row(s) are porcessed.
# 14001 row(s) are porcessed.
# 15001 row(s) are porcessed.
# 16001 row(s) are porcessed.
# 17001 row(s) are porcessed.
# 18001 row(s) are porcessed.
# 19001 row(s) are porcessed.
# 20001 row(s) are porcessed.
# 21001 row(s) are porcessed.
# 22001 row(s) are porcessed.
# 23001 row(s) are porcessed.
# 24001 row(s) are porcessed.
# 25001 row(s) are porcessed.
# 26001 row(s) are porcessed.
# 27001 row(s) are porcessed.
# 28001 row(s) are porcessed.
# 29001 row(s) are porcessed.
# 30001 row(s) are porcessed.
# 31001 row(s) are porcessed.
# 32001 row(s) are porcessed.
# 33001 row(s) are porcessed.
# 34001 row(s) are porcessed.
# 35001 row(s) are porcessed.
# 36001 row(s) are porcessed.
# 37001 row(s) are porcessed.
# 38001 row(s) are porcessed.
# 39001 row(s) are porcessed.
# 40001 row(s) are porcessed.
# 41001 row(s) are porcessed.
# 42001 row(s) are porcessed.
# 43001 row(s) are porcessed.
# 44001 row(s) are porcessed.
# 45001 row(s) are porcessed.
# 46001 row(s) are porcessed.
# 47001 row(s) are porcessed.
# 48001 row(s) are porcessed.
# 49001 row(s) are porcessed.
# 50001 row(s) are porcessed.
# 51001 row(s) are porcessed.
# 52001 row(s) are porcessed.
# 53001 row(s) are porcessed.
# 54001 row(s) are porcessed.
# 55001 row(s) are porcessed.
# 56001 row(s) are porcessed.
# 57001 row(s) are porcessed.
# 58001 row(s) are porcessed.
# 59001 row(s) are porcessed.
# 60001 row(s) are porcessed.
# 61001 row(s) are porcessed.
# 62001 row(s) are porcessed.
# 63001 row(s) are porcessed.
# 64001 row(s) are porcessed.
# 65001 row(s) are porcessed.
# 66001 row(s) are porcessed.
# 67001 row(s) are porcessed.
# 68001 row(s) are porcessed.
# 69001 row(s) are porcessed.
# 70001 row(s) are porcessed.
# 71001 row(s) are porcessed.
# 72001 row(s) are porcessed.
# 73001 row(s) are porcessed.
# 74001 row(s) are porcessed.
# 75001 row(s) are porcessed.
# 76001 row(s) are porcessed.
# 77001 row(s) are porcessed.
# 78001 row(s) are porcessed.
# 79001 row(s) are porcessed.
# 80001 row(s) are porcessed.
# 81001 row(s) are porcessed.
# 82001 row(s) are porcessed.
# 83001 row(s) are porcessed.
# 84001 row(s) are porcessed.
# 85001 row(s) are porcessed.
# 86001 row(s) are porcessed.
# 87001 row(s) are porcessed.
# 88001 row(s) are porcessed.
# 89001 row(s) are porcessed.
# 90001 row(s) are porcessed.
# 91001 row(s) are porcessed.
# 92001 row(s) are porcessed.
# 93001 row(s) are porcessed.
# 94001 row(s) are porcessed.
# 95001 row(s) are porcessed.
# 96001 row(s) are porcessed.
# 97001 row(s) are porcessed.
# 98001 row(s) are porcessed.
# 99001 row(s) are porcessed.
# 100001 row(s) are porcessed.
# 101001 row(s) are porcessed.
# 102001 row(s) are porcessed.
# 103001 row(s) are porcessed.
# 104001 row(s) are porcessed.
# 105001 row(s) are porcessed.
# 106001 row(s) are porcessed.
# 107001 row(s) are porcessed.
# 108001 row(s) are porcessed.
# 109001 row(s) are porcessed.
# 110001 row(s) are porcessed.
# 111001 row(s) are porcessed.
# 112001 row(s) are porcessed.
# 113001 row(s) are porcessed.
# 114001 row(s) are porcessed.
# 115001 row(s) are porcessed.
# 116001 row(s) are porcessed.
# 117001 row(s) are porcessed.
# 118001 row(s) are porcessed.
# 119001 row(s) are porcessed.
# 120001 row(s) are porcessed.
# 121001 row(s) are porcessed.
# 122001 row(s) are porcessed.
# 123001 row(s) are porcessed.
# 124001 row(s) are porcessed.
# 125001 row(s) are porcessed.
# 126001 row(s) are porcessed.
# 127001 row(s) are porcessed.
# 128001 row(s) are porcessed.
# 129001 row(s) are porcessed.
# 130001 row(s) are porcessed.
# 131001 row(s) are porcessed.
# 132001 row(s) are porcessed.
# 133001 row(s) are porcessed.
# 134001 row(s) are porcessed.
# 135001 row(s) are porcessed.
# 136001 row(s) are porcessed.
# 137001 row(s) are porcessed.
# 138001 row(s) are porcessed.
# 139001 row(s) are porcessed.
# 140001 row(s) are porcessed.
# 141001 row(s) are porcessed.
# 142001 row(s) are porcessed.
# 143001 row(s) are porcessed.
# 144001 row(s) are porcessed.
# 145001 row(s) are porcessed.
# 146001 row(s) are porcessed.
# 147001 row(s) are porcessed.
# 148001 row(s) are porcessed.
# 149001 row(s) are porcessed.
# 150001 row(s) are porcessed.
# 151001 row(s) are porcessed.
# 152001 row(s) are porcessed.
# 153001 row(s) are porcessed.
# 154001 row(s) are porcessed.
# 155001 row(s) are porcessed.
# 156001 row(s) are porcessed.
# 157001 row(s) are porcessed.
# 158001 row(s) are porcessed.
# 159001 row(s) are porcessed.
# 160001 row(s) are porcessed.
# 161001 row(s) are porcessed.
# 162001 row(s) are porcessed.
# 163001 row(s) are porcessed.
# 164001 row(s) are porcessed.
# 165001 row(s) are porcessed.
# 166001 row(s) are porcessed.
# 167001 row(s) are porcessed.
# 168001 row(s) are porcessed.
# 169001 row(s) are porcessed.
# 170001 row(s) are porcessed.
# 171001 row(s) are porcessed.
# 172001 row(s) are porcessed.
# 173001 row(s) are porcessed.
# 174001 row(s) are porcessed.
# 175001 row(s) are porcessed.
# 176001 row(s) are porcessed.
# 177001 row(s) are porcessed.
# 178001 row(s) are porcessed.
# 179001 row(s) are porcessed.
# 180001 row(s) are porcessed.
# 181001 row(s) are porcessed.
# 182001 row(s) are porcessed.
# 183001 row(s) are porcessed.
# 184001 row(s) are porcessed.
# 185001 row(s) are porcessed.
# 186001 row(s) are porcessed.
# 187001 row(s) are porcessed.
# 188001 row(s) are porcessed.
# 189001 row(s) are porcessed.
# 190001 row(s) are porcessed.
# 191001 row(s) are porcessed.
# 192001 row(s) are porcessed.
# 193001 row(s) are porcessed.
# 194001 row(s) are porcessed.
# 195001 row(s) are porcessed.
# 196001 row(s) are porcessed.
# 197001 row(s) are porcessed.
# 198001 row(s) are porcessed.
# 199001 row(s) are porcessed.
# 200001 row(s) are porcessed.
# 201001 row(s) are porcessed.
# 202001 row(s) are porcessed.
# 203001 row(s) are porcessed.
# 204001 row(s) are porcessed.
# 205001 row(s) are porcessed.
# 206001 row(s) are porcessed.
# 207001 row(s) are porcessed.
# 208001 row(s) are porcessed.
# 209001 row(s) are porcessed.
# 210001 row(s) are porcessed.
# 211001 row(s) are porcessed.
# 212001 row(s) are porcessed.
# 213001 row(s) are porcessed.
# 214001 row(s) are porcessed.
# 215001 row(s) are porcessed.
# 216001 row(s) are porcessed.
# 217001 row(s) are porcessed.
# 218001 row(s) are porcessed.
# 219001 row(s) are porcessed.
# 220001 row(s) are porcessed.
# 221001 row(s) are porcessed.
# 222001 row(s) are porcessed.
# 223001 row(s) are porcessed.
# 224001 row(s) are porcessed.
# 225001 row(s) are porcessed.
# 226001 row(s) are porcessed.
# 227001 row(s) are porcessed.
# 228001 row(s) are porcessed.
# 229001 row(s) are porcessed.
# 230001 row(s) are porcessed.
# 231001 row(s) are porcessed.
# 232001 row(s) are porcessed.
# 233001 row(s) are porcessed.
# 234001 row(s) are porcessed.
# 235001 row(s) are porcessed.
# 236001 row(s) are porcessed.
# 237001 row(s) are porcessed.
# 238001 row(s) are porcessed.
# 239001 row(s) are porcessed.
# 240001 row(s) are porcessed.
# 241001 row(s) are porcessed.
# 242001 row(s) are porcessed.
# 243001 row(s) are porcessed.
# 244001 row(s) are porcessed.
# 245001 row(s) are porcessed.
# 246001 row(s) are porcessed.
# 247001 row(s) are porcessed.
# 248001 row(s) are porcessed.
# 249001 row(s) are porcessed.
# 250001 row(s) are porcessed.
# 251001 row(s) are porcessed.
# 252001 row(s) are porcessed.
# 253001 row(s) are porcessed.
# 254001 row(s) are porcessed.
# 255001 row(s) are porcessed.
# 256001 row(s) are porcessed.
# 257001 row(s) are porcessed.
# 258001 row(s) are porcessed.
# 259001 row(s) are porcessed.
# 260001 row(s) are porcessed.
# 261001 row(s) are porcessed.
# 262001 row(s) are porcessed.
# 263001 row(s) are porcessed.
# 264001 row(s) are porcessed.
# 265001 row(s) are porcessed.
# 266001 row(s) are porcessed.
# 267001 row(s) are porcessed.
# 268001 row(s) are porcessed.
# 269001 row(s) are porcessed.
# 270001 row(s) are porcessed.
# 271001 row(s) are porcessed.
# 272001 row(s) are porcessed.
# 273001 row(s) are porcessed.
# 274001 row(s) are porcessed.
# 275001 row(s) are porcessed.
# 276001 row(s) are porcessed.
# 277001 row(s) are porcessed.
# 278001 row(s) are porcessed.
# 279001 row(s) are porcessed.
# 280001 row(s) are porcessed.
# 281001 row(s) are porcessed.
# 282001 row(s) are porcessed.
# 283001 row(s) are porcessed.
# 284001 row(s) are porcessed.
# 285001 row(s) are porcessed.
# 286001 row(s) are porcessed.
# 287001 row(s) are porcessed.
# 288001 row(s) are porcessed.
# 289001 row(s) are porcessed.
# 290001 row(s) are porcessed.
# 291001 row(s) are porcessed.
# 292001 row(s) are porcessed.
# 293001 row(s) are porcessed.
# 294001 row(s) are porcessed.
# 295001 row(s) are porcessed.
# 296001 row(s) are porcessed.
# 297001 row(s) are porcessed.
# 298001 row(s) are porcessed.
# 299001 row(s) are porcessed.
# 300001 row(s) are porcessed.
# 301001 row(s) are porcessed.
# 302001 row(s) are porcessed.
# 303001 row(s) are porcessed.
# 304001 row(s) are porcessed.
# 305001 row(s) are porcessed.
# 306001 row(s) are porcessed.
# 307001 row(s) are porcessed.
# 308001 row(s) are porcessed.
# 309001 row(s) are porcessed.
# 310001 row(s) are porcessed.
# 311001 row(s) are porcessed.
# 312001 row(s) are porcessed.
# 313001 row(s) are porcessed.
# 314001 row(s) are porcessed.
# 315001 row(s) are porcessed.
# 316001 row(s) are porcessed.
# 317001 row(s) are porcessed.
# 318001 row(s) are porcessed.
# 319001 row(s) are porcessed.
# 320001 row(s) are porcessed.
# 321001 row(s) are porcessed.
# 322001 row(s) are porcessed.
# 323001 row(s) are porcessed.
# 324001 row(s) are porcessed.
# 325001 row(s) are porcessed.
# 326001 row(s) are porcessed.
# 327001 row(s) are porcessed.
# 328001 row(s) are porcessed.
# 329001 row(s) are porcessed.
# 330001 row(s) are porcessed.
# 331001 row(s) are porcessed.
# 332001 row(s) are porcessed.
# 333001 row(s) are porcessed.
# 334001 row(s) are porcessed.
# 335001 row(s) are porcessed.
# 336001 row(s) are porcessed.
# 337001 row(s) are porcessed.
# 338001 row(s) are porcessed.
# 339001 row(s) are porcessed.
# 340001 row(s) are porcessed.
# 341001 row(s) are porcessed.
# 342001 row(s) are porcessed.
# 343001 row(s) are porcessed.
# 344001 row(s) are porcessed.
# 345001 row(s) are porcessed.
# 346001 row(s) are porcessed.
# 347001 row(s) are porcessed.
# 348001 row(s) are porcessed.
# 349001 row(s) are porcessed.
# 350001 row(s) are porcessed.
# 351001 row(s) are porcessed.
# 352001 row(s) are porcessed.
# 353001 row(s) are porcessed.
# 354001 row(s) are porcessed.
# 355001 row(s) are porcessed.
# 356001 row(s) are porcessed.
# 357001 row(s) are porcessed.
# 358001 row(s) are porcessed.
# 359001 row(s) are porcessed.
# 360001 row(s) are porcessed.
# 361001 row(s) are porcessed.
# 362001 row(s) are porcessed.
# 363001 row(s) are porcessed.
# 364001 row(s) are porcessed.
# 365001 row(s) are porcessed.
# 366001 row(s) are porcessed.
# 367001 row(s) are porcessed.
# 368001 row(s) are porcessed.
# 369001 row(s) are porcessed.
# 370001 row(s) are porcessed.
# 371001 row(s) are porcessed.
# 372001 row(s) are porcessed.
# 373001 row(s) are porcessed.
# 374001 row(s) are porcessed.
# 375001 row(s) are porcessed.
# 376001 row(s) are porcessed.
# 377001 row(s) are porcessed.
# 378001 row(s) are porcessed.
# 379001 row(s) are porcessed.
# 380001 row(s) are porcessed.
# 381001 row(s) are porcessed.
# 382001 row(s) are porcessed.
# 383001 row(s) are porcessed.
# 384001 row(s) are porcessed.
# 385001 row(s) are porcessed.
# 386001 row(s) are porcessed.
# 387001 row(s) are porcessed.
# 388001 row(s) are porcessed.
# 389001 row(s) are porcessed.
# 390001 row(s) are porcessed.
# 391001 row(s) are porcessed.
# 392001 row(s) are porcessed.
# 393001 row(s) are porcessed.
# 394001 row(s) are porcessed.
# 395001 row(s) are porcessed.
# 396001 row(s) are porcessed.
# 397001 row(s) are porcessed.
# 398001 row(s) are porcessed.
# 399001 row(s) are porcessed.
# 400001 row(s) are porcessed.
# 401001 row(s) are porcessed.
# 402001 row(s) are porcessed.
# 403001 row(s) are porcessed.
# 404001 row(s) are porcessed.
# 405001 row(s) are porcessed.
# 406001 row(s) are porcessed.
# 407001 row(s) are porcessed.
# 408001 row(s) are porcessed.
# 409001 row(s) are porcessed.
# 410001 row(s) are porcessed.
# 411001 row(s) are porcessed.
# 412001 row(s) are porcessed.
# 413001 row(s) are porcessed.
# 414001 row(s) are porcessed.
# 415001 row(s) are porcessed.
# 416001 row(s) are porcessed.
# 417001 row(s) are porcessed.
# 418001 row(s) are porcessed.
# 419001 row(s) are porcessed.
# 420001 row(s) are porcessed.
# 421001 row(s) are porcessed.
# 422001 row(s) are porcessed.
# 423001 row(s) are porcessed.
# 424001 row(s) are porcessed.
# 425001 row(s) are porcessed.
# 426001 row(s) are porcessed.
# 427001 row(s) are porcessed.
# 428001 row(s) are porcessed.
# 429001 row(s) are porcessed.
# 430001 row(s) are porcessed.
# 431001 row(s) are porcessed.
# 432001 row(s) are porcessed.
# 433001 row(s) are porcessed.
# 434001 row(s) are porcessed.
# 435001 row(s) are porcessed.
# 436001 row(s) are porcessed.
# 437001 row(s) are porcessed.
# 438001 row(s) are porcessed.
# 439001 row(s) are porcessed.
# 440001 row(s) are porcessed.
# 441001 row(s) are porcessed.
# 442001 row(s) are porcessed.
# 443001 row(s) are porcessed.
# 444001 row(s) are porcessed.
# 445001 row(s) are porcessed.
# 446001 row(s) are porcessed.
# 447001 row(s) are porcessed.
# 448001 row(s) are porcessed.
# 449001 row(s) are porcessed.
# 450001 row(s) are porcessed.
# 451001 row(s) are porcessed.
# 452001 row(s) are porcessed.
# 453001 row(s) are porcessed.
# 454001 row(s) are porcessed.
# 455001 row(s) are porcessed.
# 456001 row(s) are porcessed.
# 457001 row(s) are porcessed.
# 458001 row(s) are porcessed.
# 459001 row(s) are porcessed.
# 460001 row(s) are porcessed.
# 461001 row(s) are porcessed.
# 462001 row(s) are porcessed.
# 463001 row(s) are porcessed.
# 464001 row(s) are porcessed.
# 465001 row(s) are porcessed.
# 466001 row(s) are porcessed.
# 467001 row(s) are porcessed.
# 468001 row(s) are porcessed.
# 469001 row(s) are porcessed.
# 470001 row(s) are porcessed.
# 471001 row(s) are porcessed.
# 472001 row(s) are porcessed.
# 473001 row(s) are porcessed.
# 474001 row(s) are porcessed.
# 475001 row(s) are porcessed.
# 476001 row(s) are porcessed.
# 477001 row(s) are porcessed.
# 478001 row(s) are porcessed.
# 479001 row(s) are porcessed.
# 480001 row(s) are porcessed.
# 481001 row(s) are porcessed.
# 482001 row(s) are porcessed.
# 483001 row(s) are porcessed.
# 484001 row(s) are porcessed.
# 485001 row(s) are porcessed.
# 486001 row(s) are porcessed.
# 487001 row(s) are porcessed.
# 488001 row(s) are porcessed.
# 489001 row(s) are porcessed.
# 490001 row(s) are porcessed.
# 491001 row(s) are porcessed.
# 492001 row(s) are porcessed.
# 493001 row(s) are porcessed.
# 494001 row(s) are porcessed.
# 495001 row(s) are porcessed.
# 496001 row(s) are porcessed.
# 497001 row(s) are porcessed.
# 498001 row(s) are porcessed.
# 499001 row(s) are porcessed.
# 500001 row(s) are porcessed.
# 501001 row(s) are porcessed.
# 502001 row(s) are porcessed.
# 503001 row(s) are porcessed.
# 504001 row(s) are porcessed.
# 505001 row(s) are porcessed.
# 506001 row(s) are porcessed.
# 507001 row(s) are porcessed.
# 508001 row(s) are porcessed.
# 509001 row(s) are porcessed.
# 510001 row(s) are porcessed.
# 511001 row(s) are porcessed.
# 512001 row(s) are porcessed.
# 513001 row(s) are porcessed.
# 514001 row(s) are porcessed.
# 515001 row(s) are porcessed.
# 516001 row(s) are porcessed.
# 517001 row(s) are porcessed.
# 518001 row(s) are porcessed.
# 519001 row(s) are porcessed.
# 520001 row(s) are porcessed.
# 521001 row(s) are porcessed.
# 522001 row(s) are porcessed.
# 523001 row(s) are porcessed.
# 524001 row(s) are porcessed.
# 525001 row(s) are porcessed.
# 526001 row(s) are porcessed.
# 527001 row(s) are porcessed.
# 528001 row(s) are porcessed.
# 529001 row(s) are porcessed.
# 530001 row(s) are porcessed.
# 531001 row(s) are porcessed.
# 532001 row(s) are porcessed.
# 533001 row(s) are porcessed.
# 534001 row(s) are porcessed.
# 535001 row(s) are porcessed.
# 536001 row(s) are porcessed.
# 537001 row(s) are porcessed.
# 538001 row(s) are porcessed.
# 539001 row(s) are porcessed.
# 540001 row(s) are porcessed.
# 541001 row(s) are porcessed.
# 542001 row(s) are porcessed.
# 543001 row(s) are porcessed.
# 544001 row(s) are porcessed.
# 545001 row(s) are porcessed.
# 546001 row(s) are porcessed.
# 547001 row(s) are porcessed.
# 548001 row(s) are porcessed.
# 549001 row(s) are porcessed.
# 550001 row(s) are porcessed.
# 551001 row(s) are porcessed.
# 552001 row(s) are porcessed.
# 553001 row(s) are porcessed.
# 554001 row(s) are porcessed.
# 555001 row(s) are porcessed.
# 556001 row(s) are porcessed.
# 557001 row(s) are porcessed.
# 558001 row(s) are porcessed.
# 559001 row(s) are porcessed.
# 560001 row(s) are porcessed.
# 561001 row(s) are porcessed.
# 562001 row(s) are porcessed.
# 563001 row(s) are porcessed.
# 564001 row(s) are porcessed.
# 565001 row(s) are porcessed.
# 566001 row(s) are porcessed.
# 567001 row(s) are porcessed.
# 568001 row(s) are porcessed.
# 569001 row(s) are porcessed.
# 570001 row(s) are porcessed.
# 571001 row(s) are porcessed.
# 572001 row(s) are porcessed.
# 573001 row(s) are porcessed.
# 574001 row(s) are porcessed.
# 575001 row(s) are porcessed.
# 576001 row(s) are porcessed.
# 577001 row(s) are porcessed.
# 578001 row(s) are porcessed.
# 579001 row(s) are porcessed.
# 580001 row(s) are porcessed.
# 581001 row(s) are porcessed.
# 582001 row(s) are porcessed.
# 583001 row(s) are porcessed.
# 584001 row(s) are porcessed.
# 585001 row(s) are porcessed.
# 586001 row(s) are porcessed.
# 587001 row(s) are porcessed.
# 588001 row(s) are porcessed.
# 589001 row(s) are porcessed.
# 590001 row(s) are porcessed.
# 591001 row(s) are porcessed.
# 592001 row(s) are porcessed.
# 593001 row(s) are porcessed.
# 594001 row(s) are porcessed.
# 595001 row(s) are porcessed.
# 596001 row(s) are porcessed.
# 597001 row(s) are porcessed.
# 598001 row(s) are porcessed.
# 599001 row(s) are porcessed.
# 600001 row(s) are porcessed.
# 601001 row(s) are porcessed.
# 602001 row(s) are porcessed.
# 603001 row(s) are porcessed.
# 604001 row(s) are porcessed.
# 605001 row(s) are porcessed.
# 606001 row(s) are porcessed.
# 607001 row(s) are porcessed.
# 608001 row(s) are porcessed.
# 609001 row(s) are porcessed.
# 610001 row(s) are porcessed.
# 611001 row(s) are porcessed.
# 612001 row(s) are porcessed.
# 613001 row(s) are porcessed.
# 614001 row(s) are porcessed.
# 615001 row(s) are porcessed.
# 616001 row(s) are porcessed.
# 617001 row(s) are porcessed.
# 618001 row(s) are porcessed.
# 619001 row(s) are porcessed.
# 620001 row(s) are porcessed.
# 621001 row(s) are porcessed.
# 622001 row(s) are porcessed.
# 623001 row(s) are porcessed.
# 624001 row(s) are porcessed.
# 625001 row(s) are porcessed.
# 626001 row(s) are porcessed.
# 627001 row(s) are porcessed.
# 628001 row(s) are porcessed.
# 629001 row(s) are porcessed.
# 630001 row(s) are porcessed.
# 631001 row(s) are porcessed.
# 632001 row(s) are porcessed.
# 633001 row(s) are porcessed.
# 634001 row(s) are porcessed.
# 635001 row(s) are porcessed.
# 636001 row(s) are porcessed.
# 637001 row(s) are porcessed.
# 638001 row(s) are porcessed.
# 639001 row(s) are porcessed.
# 640001 row(s) are porcessed.
# 641001 row(s) are porcessed.
# 642001 row(s) are porcessed.
# 643001 row(s) are porcessed.
# 644001 row(s) are porcessed.
# 645001 row(s) are porcessed.
# 646001 row(s) are porcessed.
# 647001 row(s) are porcessed.
# 648001 row(s) are porcessed.
# 649001 row(s) are porcessed.
# 650001 row(s) are porcessed.
# 651001 row(s) are porcessed.
# 652001 row(s) are porcessed.
# 653001 row(s) are porcessed.
# 654001 row(s) are porcessed.
# 655001 row(s) are porcessed.
# 656001 row(s) are porcessed.
# 657001 row(s) are porcessed.
# 658001 row(s) are porcessed.
# 659001 row(s) are porcessed.
# 660001 row(s) are porcessed.
# 661001 row(s) are porcessed.
# 662001 row(s) are porcessed.
# 663001 row(s) are porcessed.
# 664001 row(s) are porcessed.
# 665001 row(s) are porcessed.
# 666001 row(s) are porcessed.
# 667001 row(s) are porcessed.
# 668001 row(s) are porcessed.
# 669001 row(s) are porcessed.
# 670001 row(s) are porcessed.
# 671001 row(s) are porcessed.
# 672001 row(s) are porcessed.
# 673001 row(s) are porcessed.
# 674001 row(s) are porcessed.
# 675001 row(s) are porcessed.
# 676001 row(s) are porcessed.
# 677001 row(s) are porcessed.
# 678001 row(s) are porcessed.
# 679001 row(s) are porcessed.
# 680001 row(s) are porcessed.
# 681001 row(s) are porcessed.
# 682001 row(s) are porcessed.
# 683001 row(s) are porcessed.
# 684001 row(s) are porcessed.
# 685001 row(s) are porcessed.
# 686001 row(s) are porcessed.
# 687001 row(s) are porcessed.
# 688001 row(s) are porcessed.
# 689001 row(s) are porcessed.
# 690001 row(s) are porcessed.
# 691001 row(s) are porcessed.
# 692001 row(s) are porcessed.
# 693001 row(s) are porcessed.
# 694001 row(s) are porcessed.
# 695001 row(s) are porcessed.
# 696001 row(s) are porcessed.
# 697001 row(s) are porcessed.
# 698001 row(s) are porcessed.
# 699001 row(s) are porcessed.
# 700001 row(s) are porcessed.
# 701001 row(s) are porcessed.
# 702001 row(s) are porcessed.
# 703001 row(s) are porcessed.
# 704001 row(s) are porcessed.
# 705001 row(s) are porcessed.
# 706001 row(s) are porcessed.
# 707001 row(s) are porcessed.
# 708001 row(s) are porcessed.
# 709001 row(s) are porcessed.
# 710001 row(s) are porcessed.
# 711001 row(s) are porcessed.
# 712001 row(s) are porcessed.
# 713001 row(s) are porcessed.
# 714001 row(s) are porcessed.
# 715001 row(s) are porcessed.
# 716001 row(s) are porcessed.
# 717001 row(s) are porcessed.
# 718001 row(s) are porcessed.
# 719001 row(s) are porcessed.
# 720001 row(s) are porcessed.
# 721001 row(s) are porcessed.
# 722001 row(s) are porcessed.
# 723001 row(s) are porcessed.
# 724001 row(s) are porcessed.
# 725001 row(s) are porcessed.
# 726001 row(s) are porcessed.
# 727001 row(s) are porcessed.
# 728001 row(s) are porcessed.
# 729001 row(s) are porcessed.
# 730001 row(s) are porcessed.
# 731001 row(s) are porcessed.
# 732001 row(s) are porcessed.
# 733001 row(s) are porcessed.
# 734001 row(s) are porcessed.
# 735001 row(s) are porcessed.
# 736001 row(s) are porcessed.
# 737001 row(s) are porcessed.
# 738001 row(s) are porcessed.
# 739001 row(s) are porcessed.
# 740001 row(s) are porcessed.
# 741001 row(s) are porcessed.
# 742001 row(s) are porcessed.
# 743001 row(s) are porcessed.
# 744001 row(s) are porcessed.
# 745001 row(s) are porcessed.
# 746001 row(s) are porcessed.
# 747001 row(s) are porcessed.
# 748001 row(s) are porcessed.
# 749001 row(s) are porcessed.
# 750001 row(s) are porcessed.
# 751001 row(s) are porcessed.
# 752001 row(s) are porcessed.
# 753001 row(s) are porcessed.
# 754001 row(s) are porcessed.
# 755001 row(s) are porcessed.
# 756001 row(s) are porcessed.
# 757001 row(s) are porcessed.
# 758001 row(s) are porcessed.
# 759001 row(s) are porcessed.
# 760001 row(s) are porcessed.
# 761001 row(s) are porcessed.
# 762001 row(s) are porcessed.
# 763001 row(s) are porcessed.
# 764001 row(s) are porcessed.
# 765001 row(s) are porcessed.
# 766001 row(s) are porcessed.
# 767001 row(s) are porcessed.
# 768001 row(s) are porcessed.
# 769001 row(s) are porcessed.
# 770001 row(s) are porcessed.
# 771001 row(s) are porcessed.
# 772001 row(s) are porcessed.
# 773001 row(s) are porcessed.
# 774001 row(s) are porcessed.
# 775001 row(s) are porcessed.
# 776001 row(s) are porcessed.
# 777001 row(s) are porcessed.
# 778001 row(s) are porcessed.
# 779001 row(s) are porcessed.
# 780001 row(s) are porcessed.
# 781001 row(s) are porcessed.
# 782001 row(s) are porcessed.
# 783001 row(s) are porcessed.
# 784001 row(s) are porcessed.
# 785001 row(s) are porcessed.
# 786001 row(s) are porcessed.
# 787001 row(s) are porcessed.
# 788001 row(s) are porcessed.
# 789001 row(s) are porcessed.
# 790001 row(s) are porcessed.
# 791001 row(s) are porcessed.
# 792001 row(s) are porcessed.
# 793001 row(s) are porcessed.
# 794001 row(s) are porcessed.
# 795001 row(s) are porcessed.
# 796001 row(s) are porcessed.
# 797001 row(s) are porcessed.
# 798001 row(s) are porcessed.
# 799001 row(s) are porcessed.
# 800001 row(s) are porcessed.
# 801001 row(s) are porcessed.
# 802001 row(s) are porcessed.
# 803001 row(s) are porcessed.
# 804001 row(s) are porcessed.
# 805001 row(s) are porcessed.
# 806001 row(s) are porcessed.
# 807001 row(s) are porcessed.
# 808001 row(s) are porcessed.
# 809001 row(s) are porcessed.
# 810001 row(s) are porcessed.
# 811001 row(s) are porcessed.
# 812001 row(s) are porcessed.
# 813001 row(s) are porcessed.
# 814001 row(s) are porcessed.
# 815001 row(s) are porcessed.
# 816001 row(s) are porcessed.
# 817001 row(s) are porcessed.
# 818001 row(s) are porcessed.
# 819001 row(s) are porcessed.
# 820001 row(s) are porcessed.
# 821001 row(s) are porcessed.
# 822001 row(s) are porcessed.
# 823001 row(s) are porcessed.
# 824001 row(s) are porcessed.
# 825001 row(s) are porcessed.
# 826001 row(s) are porcessed.
# 827001 row(s) are porcessed.
# 828001 row(s) are porcessed.
# 829001 row(s) are porcessed.
# 830001 row(s) are porcessed.
# 831001 row(s) are porcessed.
# 832001 row(s) are porcessed.
# 833001 row(s) are porcessed.
# 834001 row(s) are porcessed.
# 835001 row(s) are porcessed.
# 836001 row(s) are porcessed.
# 837001 row(s) are porcessed.
# 838001 row(s) are porcessed.
# 839001 row(s) are porcessed.
# 840001 row(s) are porcessed.
# 841001 row(s) are porcessed.
# 842001 row(s) are porcessed.
# 843001 row(s) are porcessed.
# 844001 row(s) are porcessed.
# 845001 row(s) are porcessed.
# 846001 row(s) are porcessed.
# 847001 row(s) are porcessed.
# 848001 row(s) are porcessed.
# 849001 row(s) are porcessed.
# 850001 row(s) are porcessed.
# 851001 row(s) are porcessed.
# 852001 row(s) are porcessed.
# 853001 row(s) are porcessed.
# 854001 row(s) are porcessed.
# 855001 row(s) are porcessed.
# 856001 row(s) are porcessed.
# 857001 row(s) are porcessed.
# 858001 row(s) are porcessed.
# 859001 row(s) are porcessed.
# 860001 row(s) are porcessed.
# 861001 row(s) are porcessed.
# 862001 row(s) are porcessed.
# 863001 row(s) are porcessed.
# 864001 row(s) are porcessed.
# 865001 row(s) are porcessed.
# 866001 row(s) are porcessed.
# 867001 row(s) are porcessed.
# 868001 row(s) are porcessed.
# 869001 row(s) are porcessed.
# 870001 row(s) are porcessed.
# 871001 row(s) are porcessed.
# 872001 row(s) are porcessed.
# 873001 row(s) are porcessed.
# 874001 row(s) are porcessed.
# 875001 row(s) are porcessed.
# 876001 row(s) are porcessed.
# 877001 row(s) are porcessed.
# 878001 row(s) are porcessed.
# 879001 row(s) are porcessed.
# 880001 row(s) are porcessed.
# 881001 row(s) are porcessed.
# 882001 row(s) are porcessed.
# 883001 row(s) are porcessed.
# 884001 row(s) are porcessed.
# 885001 row(s) are porcessed.
# 886001 row(s) are porcessed.
# 887001 row(s) are porcessed.
# 888001 row(s) are porcessed.
# 889001 row(s) are porcessed.
# 890001 row(s) are porcessed.
# 891001 row(s) are porcessed.
# 892001 row(s) are porcessed.
# 893001 row(s) are porcessed.
# 894001 row(s) are porcessed.
# 895001 row(s) are porcessed.
# 896001 row(s) are porcessed.
# 897001 row(s) are porcessed.
# 898001 row(s) are porcessed.
# 899001 row(s) are porcessed.
# 900001 row(s) are porcessed.
# 901001 row(s) are porcessed.
# 902001 row(s) are porcessed.
# 903001 row(s) are porcessed.
# 904001 row(s) are porcessed.
# 905001 row(s) are porcessed.
# 906001 row(s) are porcessed.
# 907001 row(s) are porcessed.
# 908001 row(s) are porcessed.
# 909001 row(s) are porcessed.
# 910001 row(s) are porcessed.
# 911001 row(s) are porcessed.
# 912001 row(s) are porcessed.
# 913001 row(s) are porcessed.
# 914001 row(s) are porcessed.
# 915001 row(s) are porcessed.
# 916001 row(s) are porcessed.
# 917001 row(s) are porcessed.
# 918001 row(s) are porcessed.
# 919001 row(s) are porcessed.
# 920001 row(s) are porcessed.
# 921001 row(s) are porcessed.
# 922001 row(s) are porcessed.
# 923001 row(s) are porcessed.
# 924001 row(s) are porcessed.
# 925001 row(s) are porcessed.
# 926001 row(s) are porcessed.
# 927001 row(s) are porcessed.
# 928001 row(s) are porcessed.
# 929001 row(s) are porcessed.
# 930001 row(s) are porcessed.
# 931001 row(s) are porcessed.
# 932001 row(s) are porcessed.
# 933001 row(s) are porcessed.
# 934001 row(s) are porcessed.
# 935001 row(s) are porcessed.
# 936001 row(s) are porcessed.
# 937001 row(s) are porcessed.
# 938001 row(s) are porcessed.
# 939001 row(s) are porcessed.
# 940001 row(s) are porcessed.
# 941001 row(s) are porcessed.
# 942001 row(s) are porcessed.
# 943001 row(s) are porcessed.
# 944001 row(s) are porcessed.
# 945001 row(s) are porcessed.
# 946001 row(s) are porcessed.
# 947001 row(s) are porcessed.
# 948001 row(s) are porcessed.
# 949001 row(s) are porcessed.
# 950001 row(s) are porcessed.
# 951001 row(s) are porcessed.
# 952001 row(s) are porcessed.
# 953001 row(s) are porcessed.
# 954001 row(s) are porcessed.
# 955001 row(s) are porcessed.
# 956001 row(s) are porcessed.
# 957001 row(s) are porcessed.
# 958001 row(s) are porcessed.
# 959001 row(s) are porcessed.
# 960001 row(s) are porcessed.
# 961001 row(s) are porcessed.
# 962001 row(s) are porcessed.
# 963001 row(s) are porcessed.
# 964001 row(s) are porcessed.
# 965001 row(s) are porcessed.
# 966001 row(s) are porcessed.
# 967001 row(s) are porcessed.
# 968001 row(s) are porcessed.
# 969001 row(s) are porcessed.
# 970001 row(s) are porcessed.
# 971001 row(s) are porcessed.
# 972001 row(s) are porcessed.
# 973001 row(s) are porcessed.
# 974001 row(s) are porcessed.
# 975001 row(s) are porcessed.
# 976001 row(s) are porcessed.
# 977001 row(s) are porcessed.
# 978001 row(s) are porcessed.
# 979001 row(s) are porcessed.
# 980001 row(s) are porcessed.
# 981001 row(s) are porcessed.
# 982001 row(s) are porcessed.
# 983001 row(s) are porcessed.
# 984001 row(s) are porcessed.
# 985001 row(s) are porcessed.
# 986001 row(s) are porcessed.
# 987001 row(s) are porcessed.
# 988001 row(s) are porcessed.
# 989001 row(s) are porcessed.
# 990001 row(s) are porcessed.
# 991001 row(s) are porcessed.
# 992001 row(s) are porcessed.
# 993001 row(s) are porcessed.
# 994001 row(s) are porcessed.
# 995001 row(s) are porcessed.
# 996001 row(s) are porcessed.
# 997001 row(s) are porcessed.
# 998001 row(s) are porcessed.
# 999001 row(s) are porcessed.
# 1000001 row(s) are porcessed.
# 1001001 row(s) are porcessed.
# 1002001 row(s) are porcessed.
# 1003001 row(s) are porcessed.
# 1004001 row(s) are porcessed.
# 1005001 row(s) are porcessed.
# 1006001 row(s) are porcessed.
# 1007001 row(s) are porcessed.
# 1008001 row(s) are porcessed.
# 1009001 row(s) are porcessed.
# 1010001 row(s) are porcessed.
# 1011001 row(s) are porcessed.
# 1012001 row(s) are porcessed.
# 1013001 row(s) are porcessed.
# 1014001 row(s) are porcessed.
# 1015001 row(s) are porcessed.
# 1016001 row(s) are porcessed.
# 1017001 row(s) are porcessed.
# 1018001 row(s) are porcessed.
# 1019001 row(s) are porcessed.
# 1020001 row(s) are porcessed.
# 1021001 row(s) are porcessed.
# 1022001 row(s) are porcessed.
# 1023001 row(s) are porcessed.
# 1024001 row(s) are porcessed.
# 1025001 row(s) are porcessed.
# 1026001 row(s) are porcessed.
# 1027001 row(s) are porcessed.
# 1028001 row(s) are porcessed.
# 1029001 row(s) are porcessed.
# 1030001 row(s) are porcessed.
# 1031001 row(s) are porcessed.
# 1032001 row(s) are porcessed.
# 1033001 row(s) are porcessed.
# 1034001 row(s) are porcessed.
# 1035001 row(s) are porcessed.
# 1036001 row(s) are porcessed.
# 1037001 row(s) are porcessed.
# 1038001 row(s) are porcessed.
# 1039001 row(s) are porcessed.
# 1040001 row(s) are porcessed.
# 1041001 row(s) are porcessed.
# 1042001 row(s) are porcessed.
# 1043001 row(s) are porcessed.
# 1044001 row(s) are porcessed.
# 1045001 row(s) are porcessed.
# 1046001 row(s) are porcessed.
# 1047001 row(s) are porcessed.
# 1048001 row(s) are porcessed.
# 1049001 row(s) are porcessed.
# 1050001 row(s) are porcessed.
# 1051001 row(s) are porcessed.
# 1052001 row(s) are porcessed.
# 1053001 row(s) are porcessed.
# 1054001 row(s) are porcessed.
# 1055001 row(s) are porcessed.
# 1056001 row(s) are porcessed.
# 1057001 row(s) are porcessed.
# 1058001 row(s) are porcessed.
# 1059001 row(s) are porcessed.
# 1060001 row(s) are porcessed.
# 1061001 row(s) are porcessed.
# 1062001 row(s) are porcessed.
# 1063001 row(s) are porcessed.
# 1064001 row(s) are porcessed.
# 1065001 row(s) are porcessed.
# 1066001 row(s) are porcessed.
# 1067001 row(s) are porcessed.
# 1068001 row(s) are porcessed.
# 1069001 row(s) are porcessed.
# 1070001 row(s) are porcessed.
# 1071001 row(s) are porcessed.
# 1072001 row(s) are porcessed.
# 1073001 row(s) are porcessed.
# 1074001 row(s) are porcessed.
# 1075001 row(s) are porcessed.
# 1076001 row(s) are porcessed.
# 1077001 row(s) are porcessed.
# 1078001 row(s) are porcessed.
# 1079001 row(s) are porcessed.
# 1080001 row(s) are porcessed.
# 1081001 row(s) are porcessed.
# 1082001 row(s) are porcessed.
# 1083001 row(s) are porcessed.
# 1084001 row(s) are porcessed.
# 1085001 row(s) are porcessed.
# 1086001 row(s) are porcessed.
# 1087001 row(s) are porcessed.
# 1088001 row(s) are porcessed.
# 1089001 row(s) are porcessed.
# 1090001 row(s) are porcessed.
# 1091001 row(s) are porcessed.
# 1092001 row(s) are porcessed.
# 1093001 row(s) are porcessed.
# 1094001 row(s) are porcessed.
# 1095001 row(s) are porcessed.
# 1096001 row(s) are porcessed.
# 1097001 row(s) are porcessed.
# 1098001 row(s) are porcessed.
# 1099001 row(s) are porcessed.
# 1100001 row(s) are porcessed.
# 1101001 row(s) are porcessed.
# 1102001 row(s) are porcessed.
# 1103001 row(s) are porcessed.
# 1104001 row(s) are porcessed.
# 1105001 row(s) are porcessed.
# 1106001 row(s) are porcessed.
# 1107001 row(s) are porcessed.
# 1108001 row(s) are porcessed.
# 1109001 row(s) are porcessed.
# 1110001 row(s) are porcessed.
# 1111001 row(s) are porcessed.
# 1112001 row(s) are porcessed.
# 1113001 row(s) are porcessed.
# 1114001 row(s) are porcessed.
# 1115001 row(s) are porcessed.
# 1116001 row(s) are porcessed.
# 1117001 row(s) are porcessed.
# 1118001 row(s) are porcessed.
# 1119001 row(s) are porcessed.
# 1120001 row(s) are porcessed.
# 1121001 row(s) are porcessed.
# 1122001 row(s) are porcessed.
# 1123001 row(s) are porcessed.
# 1124001 row(s) are porcessed.
# 1125001 row(s) are porcessed.
# 1126001 row(s) are porcessed.
# 1127001 row(s) are porcessed.
# 1128001 row(s) are porcessed.
# 1129001 row(s) are porcessed.
# 1130001 row(s) are porcessed.
# 1131001 row(s) are porcessed.
# 1132001 row(s) are porcessed.
# 1133001 row(s) are porcessed.
# 1134001 row(s) are porcessed.
# 1135001 row(s) are porcessed.
# 1136001 row(s) are porcessed.
# 1137001 row(s) are porcessed.
# 1138001 row(s) are porcessed.
# 1139001 row(s) are porcessed.
# 1140001 row(s) are porcessed.
# 1141001 row(s) are porcessed.
# 1142001 row(s) are porcessed.
# 1143001 row(s) are porcessed.
# 1144001 row(s) are porcessed.
# 1145001 row(s) are porcessed.
# 1146001 row(s) are porcessed.
# 1147001 row(s) are porcessed.
# 1148001 row(s) are porcessed.
# 1149001 row(s) are porcessed.
# 1150001 row(s) are porcessed.
# 1151001 row(s) are porcessed.
# 1152001 row(s) are porcessed.
# 1153001 row(s) are porcessed.
# 1154001 row(s) are porcessed.
# 1155001 row(s) are porcessed.
# 1156001 row(s) are porcessed.
# 1157001 row(s) are porcessed.
# 1158001 row(s) are porcessed.
# 1159001 row(s) are porcessed.
# 1160001 row(s) are porcessed.
# 1161001 row(s) are porcessed.
# 1162001 row(s) are porcessed.
# 1163001 row(s) are porcessed.
# 1164001 row(s) are porcessed.
# 1165001 row(s) are porcessed.
# 1166001 row(s) are porcessed.
# 1167001 row(s) are porcessed.
# 1168001 row(s) are porcessed.
# 1169001 row(s) are porcessed.
# 1170001 row(s) are porcessed.
# 1171001 row(s) are porcessed.
# 1172001 row(s) are porcessed.
# 1173001 row(s) are porcessed.
# 1174001 row(s) are porcessed.
# 1175001 row(s) are porcessed.
# 1176001 row(s) are porcessed.
# 1177001 row(s) are porcessed.
# 1178001 row(s) are porcessed.
# 1179001 row(s) are porcessed.
# 1180001 row(s) are porcessed.
# 1181001 row(s) are porcessed.
# 1182001 row(s) are porcessed.
# 1183001 row(s) are porcessed.
# 1184001 row(s) are porcessed.
# 1185001 row(s) are porcessed.
# 1186001 row(s) are porcessed.
# 1187001 row(s) are porcessed.
# 1188001 row(s) are porcessed.
# 1189001 row(s) are porcessed.
# 1190001 row(s) are porcessed.
# 1191001 row(s) are porcessed.
# 1192001 row(s) are porcessed.
# 1193001 row(s) are porcessed.
# 1194001 row(s) are porcessed.
# 1195001 row(s) are porcessed.
# 1196001 row(s) are porcessed.
# 1197001 row(s) are porcessed.
# 1198001 row(s) are porcessed.
# 1199001 row(s) are porcessed.
# 1200001 row(s) are porcessed.
# 1201001 row(s) are porcessed.
# 1202001 row(s) are porcessed.
# 1203001 row(s) are porcessed.
# 1204001 row(s) are porcessed.
# 1205001 row(s) are porcessed.
# 1206001 row(s) are porcessed.
# 1207001 row(s) are porcessed.
# 1208001 row(s) are porcessed.
# 1209001 row(s) are porcessed.
# 1210001 row(s) are porcessed.
# 1211001 row(s) are porcessed.
# 1212001 row(s) are porcessed.
# 1213001 row(s) are porcessed.
# 1214001 row(s) are porcessed.
# 1215001 row(s) are porcessed.
# 1216001 row(s) are porcessed.
# 1217001 row(s) are porcessed.
# 1218001 row(s) are porcessed.
# 1219001 row(s) are porcessed.
# 1220001 row(s) are porcessed.
# 1221001 row(s) are porcessed.
# 1222001 row(s) are porcessed.
# 1223001 row(s) are porcessed.
# 1224001 row(s) are porcessed.
# 1225001 row(s) are porcessed.
# 1226001 row(s) are porcessed.
# 1227001 row(s) are porcessed.
# 1228001 row(s) are porcessed.
# 1229001 row(s) are porcessed.
# 1230001 row(s) are porcessed.
# 1231001 row(s) are porcessed.
# 1232001 row(s) are porcessed.
# 1233001 row(s) are porcessed.
# 1234001 row(s) are porcessed.
# 1235001 row(s) are porcessed.
# 1236001 row(s) are porcessed.
# 1237001 row(s) are porcessed.
# 1238001 row(s) are porcessed.
# 1239001 row(s) are porcessed.
# 1240001 row(s) are porcessed.
# 1241001 row(s) are porcessed.
# 1242001 row(s) are porcessed.
# 1243001 row(s) are porcessed.
# 1244001 row(s) are porcessed.
# 1245001 row(s) are porcessed.
# 1246001 row(s) are porcessed.
# 1247001 row(s) are porcessed.
# 1248001 row(s) are porcessed.
# 1249001 row(s) are porcessed.
# 1250001 row(s) are porcessed.
# 1251001 row(s) are porcessed.
# 1252001 row(s) are porcessed.
# 1253001 row(s) are porcessed.
# 1254001 row(s) are porcessed.
# 1255001 row(s) are porcessed.
# 1256001 row(s) are porcessed.
# 1257001 row(s) are porcessed.
# 1258001 row(s) are porcessed.
# 1259001 row(s) are porcessed.
# 1260001 row(s) are porcessed.
# 1261001 row(s) are porcessed.
# 1262001 row(s) are porcessed.
# 1263001 row(s) are porcessed.
# 1264001 row(s) are porcessed.
# 1265001 row(s) are porcessed.
# 1266001 row(s) are porcessed.
# 1267001 row(s) are porcessed.
# 1268001 row(s) are porcessed.
# 1269001 row(s) are porcessed.
# 1270001 row(s) are porcessed.
# 1271001 row(s) are porcessed.
# 1272001 row(s) are porcessed.
# 1273001 row(s) are porcessed.
# 1274001 row(s) are porcessed.
# 1275001 row(s) are porcessed.
# 1276001 row(s) are porcessed.
# 1277001 row(s) are porcessed.
# 1278001 row(s) are porcessed.
# 1279001 row(s) are porcessed.
# 1280001 row(s) are porcessed.
# 1281001 row(s) are porcessed.
# 1282001 row(s) are porcessed.
# 1283001 row(s) are porcessed.
# 1284001 row(s) are porcessed.
# 1285001 row(s) are porcessed.
# 1286001 row(s) are porcessed.
# 1287001 row(s) are porcessed.
# 1288001 row(s) are porcessed.
# 1289001 row(s) are porcessed.
# 1290001 row(s) are porcessed.
# 1291001 row(s) are porcessed.
# 1292001 row(s) are porcessed.
# 1293001 row(s) are porcessed.
# 1294001 row(s) are porcessed.
# 1295001 row(s) are porcessed.
# 1296001 row(s) are porcessed.
# 1297001 row(s) are porcessed.
# 1298001 row(s) are porcessed.
# 1299001 row(s) are porcessed.
# 1300001 row(s) are porcessed.
# 1301001 row(s) are porcessed.
# 1302001 row(s) are porcessed.
# 1303001 row(s) are porcessed.
# 1304001 row(s) are porcessed.
# 1305001 row(s) are porcessed.
# 1306001 row(s) are porcessed.
# 1307001 row(s) are porcessed.
# 1308001 row(s) are porcessed.
# 1309001 row(s) are porcessed.
# 1310001 row(s) are porcessed.
# 1311001 row(s) are porcessed.
# 1312001 row(s) are porcessed.
# 1313001 row(s) are porcessed.
# 1314001 row(s) are porcessed.
# 1315001 row(s) are porcessed.
# 1316001 row(s) are porcessed.
# 1317001 row(s) are porcessed.
# 1318001 row(s) are porcessed.
# 1319001 row(s) are porcessed.
# 1320001 row(s) are porcessed.
# 1321001 row(s) are porcessed.
# 1322001 row(s) are porcessed.
# 1323001 row(s) are porcessed.
# 1324001 row(s) are porcessed.
# 1325001 row(s) are porcessed.
# 1326001 row(s) are porcessed.
# 1327001 row(s) are porcessed.
# 1328001 row(s) are porcessed.
# 1329001 row(s) are porcessed.
# 1330001 row(s) are porcessed.
# 1331001 row(s) are porcessed.
# 1332001 row(s) are porcessed.
# 1333001 row(s) are porcessed.
# 1334001 row(s) are porcessed.
# 1335001 row(s) are porcessed.
# 1336001 row(s) are porcessed.
# 1337001 row(s) are porcessed.
# 1338001 row(s) are porcessed.
# 1339001 row(s) are porcessed.
# 1340001 row(s) are porcessed.
# 1341001 row(s) are porcessed.
# 1342001 row(s) are porcessed.
# 1343001 row(s) are porcessed.
# 1344001 row(s) are porcessed.
# 1345001 row(s) are porcessed.
# 1346001 row(s) are porcessed.
# 1347001 row(s) are porcessed.
# 1348001 row(s) are porcessed.
# 1349001 row(s) are porcessed.
# 1350001 row(s) are porcessed.
# 1351001 row(s) are porcessed.
# 1352001 row(s) are porcessed.
# 1353001 row(s) are porcessed.
# 1354001 row(s) are porcessed.
# 1355001 row(s) are porcessed.
# 1356001 row(s) are porcessed.
# 1357001 row(s) are porcessed.
# 1358001 row(s) are porcessed.
# 1359001 row(s) are porcessed.
# 1360001 row(s) are porcessed.
# 1361001 row(s) are porcessed.
# 1362001 row(s) are porcessed.
# 1363001 row(s) are porcessed.
# 1364001 row(s) are porcessed.
# 1365001 row(s) are porcessed.
# 1366001 row(s) are porcessed.
# 1367001 row(s) are porcessed.
# 1368001 row(s) are porcessed.
# 1369001 row(s) are porcessed.
# 1370001 row(s) are porcessed.
# 1371001 row(s) are porcessed.
# 1372001 row(s) are porcessed.
# 1373001 row(s) are porcessed.
# 1374001 row(s) are porcessed.
# 1375001 row(s) are porcessed.
# 1376001 row(s) are porcessed.
# 1377001 row(s) are porcessed.
# 1378001 row(s) are porcessed.
# 1379001 row(s) are porcessed.
# 1380001 row(s) are porcessed.
# 1381001 row(s) are porcessed.
# 1382001 row(s) are porcessed.
# 1383001 row(s) are porcessed.
# 1384001 row(s) are porcessed.
# 1385001 row(s) are porcessed.
# 1386001 row(s) are porcessed.
# 1387001 row(s) are porcessed.
# 1388001 row(s) are porcessed.
# 1389001 row(s) are porcessed.
# 1390001 row(s) are porcessed.
# 1391001 row(s) are porcessed.
# 1392001 row(s) are porcessed.
# 1393001 row(s) are porcessed.
# 1394001 row(s) are porcessed.
# 1395001 row(s) are porcessed.
# 1396001 row(s) are porcessed.
# 1397001 row(s) are porcessed.
# 1398001 row(s) are porcessed.
# 1399001 row(s) are porcessed.
# 1400001 row(s) are porcessed.
# 1401001 row(s) are porcessed.
# 1402001 row(s) are porcessed.
# 1403001 row(s) are porcessed.
# 1404001 row(s) are porcessed.
# 1405001 row(s) are porcessed.
# 1406001 row(s) are porcessed.
# 1407001 row(s) are porcessed.
# 1408001 row(s) are porcessed.
# 1409001 row(s) are porcessed.
# 1410001 row(s) are porcessed.
# 1411001 row(s) are porcessed.
# 1412001 row(s) are porcessed.
# 1413001 row(s) are porcessed.
# 1414001 row(s) are porcessed.
# 1415001 row(s) are porcessed.
# 1416001 row(s) are porcessed.
# 1417001 row(s) are porcessed.
# 1418001 row(s) are porcessed.
# 1419001 row(s) are porcessed.
# 1420001 row(s) are porcessed.
# 1421001 row(s) are porcessed.
# 1422001 row(s) are porcessed.
# 1423001 row(s) are porcessed.
# 1424001 row(s) are porcessed.
# 1425001 row(s) are porcessed.
# 1426001 row(s) are porcessed.
# 1427001 row(s) are porcessed.
# 1428001 row(s) are porcessed.
# 1429001 row(s) are porcessed.
# 1430001 row(s) are porcessed.
# 1431001 row(s) are porcessed.
# 1432001 row(s) are porcessed.
# 1433001 row(s) are porcessed.
# 1434001 row(s) are porcessed.
# 1435001 row(s) are porcessed.
# 1436001 row(s) are porcessed.
# 1437001 row(s) are porcessed.
# 1438001 row(s) are porcessed.
# 1439001 row(s) are porcessed.
# 1440001 row(s) are porcessed.
# 1441001 row(s) are porcessed.
# 1442001 row(s) are porcessed.
# 1443001 row(s) are porcessed.
# 1444001 row(s) are porcessed.
# 1445001 row(s) are porcessed.
# 1446001 row(s) are porcessed.
# 1447001 row(s) are porcessed.
# 1448001 row(s) are porcessed.
# 1449001 row(s) are porcessed.
# 1450001 row(s) are porcessed.
# 1451001 row(s) are porcessed.
# 1452001 row(s) are porcessed.
# 1453001 row(s) are porcessed.
# 1454001 row(s) are porcessed.
# 1455001 row(s) are porcessed.
# 1456001 row(s) are porcessed.
# 1457001 row(s) are porcessed.
# 1458001 row(s) are porcessed.
# 1459001 row(s) are porcessed.
# 1460001 row(s) are porcessed.
# 1461001 row(s) are porcessed.
# 1462001 row(s) are porcessed.
# 1463001 row(s) are porcessed.
# 1464001 row(s) are porcessed.
# 1465001 row(s) are porcessed.
# 1466001 row(s) are porcessed.
# 1467001 row(s) are porcessed.
# 1468001 row(s) are porcessed.
# 1469001 row(s) are porcessed.
# 1470001 row(s) are porcessed.
# 1471001 row(s) are porcessed.
# 1472001 row(s) are porcessed.
# 1473001 row(s) are porcessed.
# 1474001 row(s) are porcessed.
# 1475001 row(s) are porcessed.
# 1476001 row(s) are porcessed.
# 1477001 row(s) are porcessed.
# 1478001 row(s) are porcessed.
# 1479001 row(s) are porcessed.
# 1480001 row(s) are porcessed.
# 1481001 row(s) are porcessed.
# 1482001 row(s) are porcessed.
# 1483001 row(s) are porcessed.
# 1484001 row(s) are porcessed.
# 1485001 row(s) are porcessed.
# 1486001 row(s) are porcessed.
# 1487001 row(s) are porcessed.
# 1488001 row(s) are porcessed.
# 1489001 row(s) are porcessed.
# 1490001 row(s) are porcessed.
# 1491001 row(s) are porcessed.
# 1492001 row(s) are porcessed.
# 1493001 row(s) are porcessed.
# 1494001 row(s) are porcessed.
# 1495001 row(s) are porcessed.
# 1496001 row(s) are porcessed.
# 1497001 row(s) are porcessed.
# 1498001 row(s) are porcessed.
# 1499001 row(s) are porcessed.
# 1500001 row(s) are porcessed.
# 1501001 row(s) are porcessed.
# 1502001 row(s) are porcessed.
# 1503001 row(s) are porcessed.
# 1504001 row(s) are porcessed.
# 1505001 row(s) are porcessed.
# 1506001 row(s) are porcessed.
# 1507001 row(s) are porcessed.
# 1508001 row(s) are porcessed.
# 1509001 row(s) are porcessed.
# 1510001 row(s) are porcessed.
# 1511001 row(s) are porcessed.
# 1512001 row(s) are porcessed.
# 1513001 row(s) are porcessed.
# 1514001 row(s) are porcessed.
# 1515001 row(s) are porcessed.
# 1516001 row(s) are porcessed.
# 1517001 row(s) are porcessed.
# 1518001 row(s) are porcessed.
# 1519001 row(s) are porcessed.
# 1520001 row(s) are porcessed.
# 1521001 row(s) are porcessed.
# 1522001 row(s) are porcessed.
# 1523001 row(s) are porcessed.
# 1524001 row(s) are porcessed.
# 1525001 row(s) are porcessed.
# 1526001 row(s) are porcessed.
# 1527001 row(s) are porcessed.
# 1528001 row(s) are porcessed.
# 1529001 row(s) are porcessed.
# 1530001 row(s) are porcessed.
# 1531001 row(s) are porcessed.
# 1532001 row(s) are porcessed.
# 1533001 row(s) are porcessed.
# 1534001 row(s) are porcessed.
# 1535001 row(s) are porcessed.
# 1536001 row(s) are porcessed.
# 1537001 row(s) are porcessed.
# 1538001 row(s) are porcessed.
# 1539001 row(s) are porcessed.
# 1540001 row(s) are porcessed.
# 1541001 row(s) are porcessed.
# 1542001 row(s) are porcessed.
# 1543001 row(s) are porcessed.
# 1544001 row(s) are porcessed.
# 1545001 row(s) are porcessed.
# 1546001 row(s) are porcessed.
# 1547001 row(s) are porcessed.
# 1548001 row(s) are porcessed.
# 1549001 row(s) are porcessed.
# 1550001 row(s) are porcessed.
# 1551001 row(s) are porcessed.
# 1552001 row(s) are porcessed.
# 1553001 row(s) are porcessed.
# 1554001 row(s) are porcessed.
# 1555001 row(s) are porcessed.
# 1556001 row(s) are porcessed.
# 1557001 row(s) are porcessed.
# 1558001 row(s) are porcessed.
# 1559001 row(s) are porcessed.
# 1560001 row(s) are porcessed.
# 1561001 row(s) are porcessed.
# 1562001 row(s) are porcessed.
# 1563001 row(s) are porcessed.
# 1564001 row(s) are porcessed.
# 1565001 row(s) are porcessed.
# 1566001 row(s) are porcessed.
# 1567001 row(s) are porcessed.
# 1568001 row(s) are porcessed.
# 1569001 row(s) are porcessed.
# 1570001 row(s) are porcessed.
# 1571001 row(s) are porcessed.
# 1572001 row(s) are porcessed.
# 1573001 row(s) are porcessed.
# 1574001 row(s) are porcessed.
# 1575001 row(s) are porcessed.
# 1576001 row(s) are porcessed.
# 1577001 row(s) are porcessed.
# 1578001 row(s) are porcessed.
# 1579001 row(s) are porcessed.
# 1580001 row(s) are porcessed.
# 1581001 row(s) are porcessed.
# 1582001 row(s) are porcessed.
# 1583001 row(s) are porcessed.
# 1584001 row(s) are porcessed.
# 1585001 row(s) are porcessed.
# 1586001 row(s) are porcessed.
# 1587001 row(s) are porcessed.
# 1588001 row(s) are porcessed.
# 1589001 row(s) are porcessed.
# 1590001 row(s) are porcessed.
# 1591001 row(s) are porcessed.
# 1592001 row(s) are porcessed.
# 1593001 row(s) are porcessed.
# 1594001 row(s) are porcessed.
# 1595001 row(s) are porcessed.
# 1596001 row(s) are porcessed.
# 1597001 row(s) are porcessed.
# 1598001 row(s) are porcessed.
# 1599001 row(s) are porcessed.
# 1600001 row(s) are porcessed.
# 1601001 row(s) are porcessed.
# 1602001 row(s) are porcessed.
# 1603001 row(s) are porcessed.
# 1604001 row(s) are porcessed.
# 1605001 row(s) are porcessed.
# 1606001 row(s) are porcessed.
# 1607001 row(s) are porcessed.
# 1608001 row(s) are porcessed.
# 1609001 row(s) are porcessed.
# 1610001 row(s) are porcessed.
# 1611001 row(s) are porcessed.
# 1612001 row(s) are porcessed.
# 1613001 row(s) are porcessed.
# 1614001 row(s) are porcessed.
# 1615001 row(s) are porcessed.
# 1616001 row(s) are porcessed.
# 1617001 row(s) are porcessed.
# 1618001 row(s) are porcessed.
# 1619001 row(s) are porcessed.
# 1620001 row(s) are porcessed.
# 1621001 row(s) are porcessed.
# 1622001 row(s) are porcessed.
# 1623001 row(s) are porcessed.
# 1624001 row(s) are porcessed.
# 1625001 row(s) are porcessed.
# 1626001 row(s) are porcessed.
# 1627001 row(s) are porcessed.
# 1628001 row(s) are porcessed.
# 1629001 row(s) are porcessed.
# 1630001 row(s) are porcessed.
# 1631001 row(s) are porcessed.
# 1632001 row(s) are porcessed.
# 1633001 row(s) are porcessed.
# 1634001 row(s) are porcessed.
# 1635001 row(s) are porcessed.
# 1636001 row(s) are porcessed.
# ...
# 2575001 row(s) are porcessed.
# 2576001 row(s) are porcessed.
# 2577001 row(s) are porcessed.
# 2578001 row(s) are porcessed.
# 2579001 row(s) are porcessed.
# 2580001 row(s) are porcessed.
# 2581001 row(s) are porcessed.
# 2582001 row(s) are porcessed.
# 2583001 row(s) are porcessed.
# 2584001 row(s) are porcessed.
# 2585001 row(s) are porcessed.
# 2586001 row(s) are porcessed.
# 2587001 row(s) are porcessed.
# 2588001 row(s) are porcessed.
# 2589001 row(s) are porcessed.
# 2590001 row(s) are porcessed.
# 2591001 row(s) are porcessed.
# 2592001 row(s) are porcessed.
# 2593001 row(s) are porcessed.
# 2594001 row(s) are porcessed.
# 2595001 row(s) are porcessed.
# 2596001 row(s) are porcessed.
# 2597001 row(s) are porcessed.
# 2598001 row(s) are porcessed.
# 2599001 row(s) are porcessed.
# 2600001 row(s) are porcessed.
# 2601001 row(s) are porcessed.
# 2602001 row(s) are porcessed.
# 2603001 row(s) are porcessed.
# 2604001 row(s) are porcessed.
# 2605001 row(s) are porcessed.
# 2606001 row(s) are porcessed.
# 2607001 row(s) are porcessed.
# 2608001 row(s) are porcessed.
# 2609001 row(s) are porcessed.
# 2610001 row(s) are porcessed.
# 2611001 row(s) are porcessed.
# 2612001 row(s) are porcessed.
# 2613001 row(s) are porcessed.
# 2614001 row(s) are porcessed.
# 2615001 row(s) are porcessed.
# 2616001 row(s) are porcessed.
# 2617001 row(s) are porcessed.
# 2618001 row(s) are porcessed.
# 2619001 row(s) are porcessed.
# 2620001 row(s) are porcessed.
# 2621001 row(s) are porcessed.
# 2622001 row(s) are porcessed.
# 2623001 row(s) are porcessed.
# 2624001 row(s) are porcessed.
# 2625001 row(s) are porcessed.
# 2626001 row(s) are porcessed.
# 2627001 row(s) are porcessed.
# 2628001 row(s) are porcessed.
# 2629001 row(s) are porcessed.
# 2630001 row(s) are porcessed.
# 2631001 row(s) are porcessed.
# 2632001 row(s) are porcessed.
# 2633001 row(s) are porcessed.
# 2634001 row(s) are porcessed.
# 2635001 row(s) are porcessed.
# 2636001 row(s) are porcessed.
# 2637001 row(s) are porcessed.
# 2638001 row(s) are porcessed.
# 2639001 row(s) are porcessed.
# 2640001 row(s) are porcessed.
# 2641001 row(s) are porcessed.
# 2642001 row(s) are porcessed.
# 2643001 row(s) are porcessed.
# 2644001 row(s) are porcessed.
# 2645001 row(s) are porcessed.
# 2646001 row(s) are porcessed.
# 2647001 row(s) are porcessed.
# 2648001 row(s) are porcessed.
# 2649001 row(s) are porcessed.
# 2650001 row(s) are porcessed.
# 2651001 row(s) are porcessed.
# 2652001 row(s) are porcessed.
# 2653001 row(s) are porcessed.
# 2654001 row(s) are porcessed.
# 2655001 row(s) are porcessed.
# 2656001 row(s) are porcessed.
# 2657001 row(s) are porcessed.
# 2658001 row(s) are porcessed.
# 2659001 row(s) are porcessed.
# 2660001 row(s) are porcessed.
# 2661001 row(s) are porcessed.
# 2662001 row(s) are porcessed.
# 2663001 row(s) are porcessed.
# 2664001 row(s) are porcessed.
# 2665001 row(s) are porcessed.
# 2666001 row(s) are porcessed.
# 2667001 row(s) are porcessed.
# 2668001 row(s) are porcessed.
# 2669001 row(s) are porcessed.
# 2670001 row(s) are porcessed.
# 2671001 row(s) are porcessed.
# 2672001 row(s) are porcessed.
# 2673001 row(s) are porcessed.
# 2674001 row(s) are porcessed.
# 2675001 row(s) are porcessed.
# 2676001 row(s) are porcessed.
# 2677001 row(s) are porcessed.
# 2678001 row(s) are porcessed.
# 2679001 row(s) are porcessed.
# 2680001 row(s) are porcessed.
# 2681001 row(s) are porcessed.
# 2682001 row(s) are porcessed.
# 2683001 row(s) are porcessed.
# 2684001 row(s) are porcessed.
# 2685001 row(s) are porcessed.
# 2686001 row(s) are porcessed.
# 2687001 row(s) are porcessed.
# 2688001 row(s) are porcessed.
# 2689001 row(s) are porcessed.
# 2690001 row(s) are porcessed.
# 2691001 row(s) are porcessed.
# 2692001 row(s) are porcessed.
# 2693001 row(s) are porcessed.
# 2694001 row(s) are porcessed.
# 2695001 row(s) are porcessed.
# 2696001 row(s) are porcessed.
# 2697001 row(s) are porcessed.
# 2698001 row(s) are porcessed.
# 2699001 row(s) are porcessed.
# 2700001 row(s) are porcessed.
# 2701001 row(s) are porcessed.
# 2702001 row(s) are porcessed.
# 2703001 row(s) are porcessed.
# 2704001 row(s) are porcessed.
# 2705001 row(s) are porcessed.
# 2706001 row(s) are porcessed.
# 2707001 row(s) are porcessed.
# 2708001 row(s) are porcessed.
# 2709001 row(s) are porcessed.
# 2710001 row(s) are porcessed.
# 2711001 row(s) are porcessed.
# 2712001 row(s) are porcessed.
# 2713001 row(s) are porcessed.
# 2714001 row(s) are porcessed.
# 2715001 row(s) are porcessed.
# 2716001 row(s) are porcessed.
# 2717001 row(s) are porcessed.
# 2718001 row(s) are porcessed.
# 2719001 row(s) are porcessed.
# 2720001 row(s) are porcessed.
# 2721001 row(s) are porcessed.
# 2722001 row(s) are porcessed.
# 2723001 row(s) are porcessed.
# 2724001 row(s) are porcessed.
# 2725001 row(s) are porcessed.
# 2726001 row(s) are porcessed.
# 2727001 row(s) are porcessed.
# 2728001 row(s) are porcessed.
# 2729001 row(s) are porcessed.
# 2730001 row(s) are porcessed.
# 2731001 row(s) are porcessed.
# 2732001 row(s) are porcessed.
# 2733001 row(s) are porcessed.
# 2734001 row(s) are porcessed.
# 2735001 row(s) are porcessed.
# 2736001 row(s) are porcessed.
# 2737001 row(s) are porcessed.
# 2738001 row(s) are porcessed.
# 2739001 row(s) are porcessed.
# 2740001 row(s) are porcessed.
# 2741001 row(s) are porcessed.
# 2742001 row(s) are porcessed.
# 2743001 row(s) are porcessed.
# 2744001 row(s) are porcessed.
# 2745001 row(s) are porcessed.
# 2746001 row(s) are porcessed.
# 2747001 row(s) are porcessed.
# 2748001 row(s) are porcessed.
# 2749001 row(s) are porcessed.
# 2750001 row(s) are porcessed.
# 2751001 row(s) are porcessed.
# 2752001 row(s) are porcessed.
# 2753001 row(s) are porcessed.
# 2754001 row(s) are porcessed.
# 2755001 row(s) are porcessed.
# 2756001 row(s) are porcessed.
# 2757001 row(s) are porcessed.
# 2758001 row(s) are porcessed.
# 2759001 row(s) are porcessed.
# 2760001 row(s) are porcessed.
# 2761001 row(s) are porcessed.
# 2762001 row(s) are porcessed.
# 2763001 row(s) are porcessed.
# 2764001 row(s) are porcessed.
# 2765001 row(s) are porcessed.
# 2766001 row(s) are porcessed.
# 2767001 row(s) are porcessed.
# 2768001 row(s) are porcessed.
# 2769001 row(s) are porcessed.
# 2770001 row(s) are porcessed.
# 2771001 row(s) are porcessed.
# 2772001 row(s) are porcessed.
# 2773001 row(s) are porcessed.
# 2774001 row(s) are porcessed.
# 2775001 row(s) are porcessed.
# 2776001 row(s) are porcessed.
# 2777001 row(s) are porcessed.
# 2778001 row(s) are porcessed.
# 2779001 row(s) are porcessed.
# 2780001 row(s) are porcessed.
# 2781001 row(s) are porcessed.
# 2782001 row(s) are porcessed.
# 2783001 row(s) are porcessed.
# 2784001 row(s) are porcessed.
# 2785001 row(s) are porcessed.
# 2786001 row(s) are porcessed.
# 2787001 row(s) are porcessed.
# 2788001 row(s) are porcessed.
# 2789001 row(s) are porcessed.
# 2790001 row(s) are porcessed.
# 2791001 row(s) are porcessed.
# 2792001 row(s) are porcessed.
# 2793001 row(s) are porcessed.
# 2794001 row(s) are porcessed.
# 2795001 row(s) are porcessed.
# 2796001 row(s) are porcessed.
# 2797001 row(s) are porcessed.
# 2798001 row(s) are porcessed.
# 2799001 row(s) are porcessed.
# 2800001 row(s) are porcessed.
# 2801001 row(s) are porcessed.
# 2802001 row(s) are porcessed.
# 2803001 row(s) are porcessed.
# 2804001 row(s) are porcessed.
# 2805001 row(s) are porcessed.
# 2806001 row(s) are porcessed.
# 2807001 row(s) are porcessed.
# 2808001 row(s) are porcessed.
# 2809001 row(s) are porcessed.
# 2810001 row(s) are porcessed.
# 2811001 row(s) are porcessed.
# 2812001 row(s) are porcessed.
# 2813001 row(s) are porcessed.
# 2814001 row(s) are porcessed.
# 2815001 row(s) are porcessed.
# 2816001 row(s) are porcessed.
# 2817001 row(s) are porcessed.
# 2818001 row(s) are porcessed.
# 2819001 row(s) are porcessed.
# 2820001 row(s) are porcessed.
# 2821001 row(s) are porcessed.
# 2822001 row(s) are porcessed.
# 2823001 row(s) are porcessed.
# 2824001 row(s) are porcessed.
# 2825001 row(s) are porcessed.
# 2826001 row(s) are porcessed.
# 2827001 row(s) are porcessed.
# 2828001 row(s) are porcessed.
# 2829001 row(s) are porcessed.
# 2830001 row(s) are porcessed.
# 2831001 row(s) are porcessed.
# 2832001 row(s) are porcessed.
# 2833001 row(s) are porcessed.
# 2834001 row(s) are porcessed.
# 2835001 row(s) are porcessed.
# 2836001 row(s) are porcessed.
# 2837001 row(s) are porcessed.
# 2838001 row(s) are porcessed.
# 2839001 row(s) are porcessed.
# 2840001 row(s) are porcessed.
# 2841001 row(s) are porcessed.
# 2842001 row(s) are porcessed.
# 2843001 row(s) are porcessed.
# 2844001 row(s) are porcessed.
# 2845001 row(s) are porcessed.
# 2846001 row(s) are porcessed.
# 2847001 row(s) are porcessed.
# 2848001 row(s) are porcessed.
# 2849001 row(s) are porcessed.
# 2850001 row(s) are porcessed.
# 2851001 row(s) are porcessed.
# 2852001 row(s) are porcessed.
# 2853001 row(s) are porcessed.
# 2854001 row(s) are porcessed.
# 2855001 row(s) are porcessed.
# 2856001 row(s) are porcessed.
# 2857001 row(s) are porcessed.
# 2858001 row(s) are porcessed.
# 2859001 row(s) are porcessed.
# 2860001 row(s) are porcessed.
# 2861001 row(s) are porcessed.
# 2862001 row(s) are porcessed.
# 2863001 row(s) are porcessed.
# 2864001 row(s) are porcessed.
# 2865001 row(s) are porcessed.
# 2866001 row(s) are porcessed.
# 2867001 row(s) are porcessed.
# 2868001 row(s) are porcessed.
# 2869001 row(s) are porcessed.
# 2870001 row(s) are porcessed.
# 2871001 row(s) are porcessed.
# 2872001 row(s) are porcessed.
# 2873001 row(s) are porcessed.
# 2874001 row(s) are porcessed.
# 2875001 row(s) are porcessed.
# 2876001 row(s) are porcessed.
# 2877001 row(s) are porcessed.
# 2878001 row(s) are porcessed.
# 2879001 row(s) are porcessed.
# 2880001 row(s) are porcessed.
# 2881001 row(s) are porcessed.
# 2882001 row(s) are porcessed.
# 2883001 row(s) are porcessed.
# 2884001 row(s) are porcessed.
# 2885001 row(s) are porcessed.
# 2886001 row(s) are porcessed.
# 2887001 row(s) are porcessed.
# 2888001 row(s) are porcessed.
# 2889001 row(s) are porcessed.
# 2890001 row(s) are porcessed.
# 2891001 row(s) are porcessed.
# 2892001 row(s) are porcessed.
# 2893001 row(s) are porcessed.
# 2894001 row(s) are porcessed.
# 2895001 row(s) are porcessed.
# 2896001 row(s) are porcessed.
# 2897001 row(s) are porcessed.
# 2898001 row(s) are porcessed.
# 2899001 row(s) are porcessed.
# 2900001 row(s) are porcessed.
# 2901001 row(s) are porcessed.
# 2902001 row(s) are porcessed.
# 2903001 row(s) are porcessed.
# 2904001 row(s) are porcessed.
# 2905001 row(s) are porcessed.
# 2906001 row(s) are porcessed.
# 2907001 row(s) are porcessed.
# 2908001 row(s) are porcessed.
# 2909001 row(s) are porcessed.
# 2910001 row(s) are porcessed.
# 2911001 row(s) are porcessed.
# 2912001 row(s) are porcessed.
# 2913001 row(s) are porcessed.
# 2914001 row(s) are porcessed.
# 2915001 row(s) are porcessed.
# 2916001 row(s) are porcessed.
# 2917001 row(s) are porcessed.
# 2918001 row(s) are porcessed.
# 2919001 row(s) are porcessed.
# 2920001 row(s) are porcessed.
# 2921001 row(s) are porcessed.
# 2922001 row(s) are porcessed.
# 2923001 row(s) are porcessed.
# 2924001 row(s) are porcessed.
# 2925001 row(s) are porcessed.
# 2926001 row(s) are porcessed.
# 2927001 row(s) are porcessed.
# 2928001 row(s) are porcessed.
# 2929001 row(s) are porcessed.
# 2930001 row(s) are porcessed.
# 2931001 row(s) are porcessed.
# 2932001 row(s) are porcessed.
# 2933001 row(s) are porcessed.
# 2934001 row(s) are porcessed.
# 2935001 row(s) are porcessed.
# 2936001 row(s) are porcessed.
# 2937001 row(s) are porcessed.
# 2938001 row(s) are porcessed.
# 2939001 row(s) are porcessed.
# 2940001 row(s) are porcessed.
# 2941001 row(s) are porcessed.
# 2942001 row(s) are porcessed.
# 2943001 row(s) are porcessed.
# 2944001 row(s) are porcessed.
# 2945001 row(s) are porcessed.
# 2946001 row(s) are porcessed.
# 2947001 row(s) are porcessed.
# 2948001 row(s) are porcessed.
# 2949001 row(s) are porcessed.
# 2950001 row(s) are porcessed.
# 2951001 row(s) are porcessed.
# 2952001 row(s) are porcessed.
# 2953001 row(s) are porcessed.
# 2954001 row(s) are porcessed.
# 2955001 row(s) are porcessed.
# 2956001 row(s) are porcessed.
# 2957001 row(s) are porcessed.
# 2958001 row(s) are porcessed.
# 2959001 row(s) are porcessed.
# 2960001 row(s) are porcessed.
# 2961001 row(s) are porcessed.
# 2962001 row(s) are porcessed.
# 2963001 row(s) are porcessed.
# 2964001 row(s) are porcessed.
# 2965001 row(s) are porcessed.
# 2966001 row(s) are porcessed.
# 2967001 row(s) are porcessed.
# 2968001 row(s) are porcessed.
# 2969001 row(s) are porcessed.
# 2970001 row(s) are porcessed.
# 2971001 row(s) are porcessed.
# 2972001 row(s) are porcessed.
# 2973001 row(s) are porcessed.
# 2974001 row(s) are porcessed.
# 2975001 row(s) are porcessed.
# 2976001 row(s) are porcessed.
# 2977001 row(s) are porcessed.
# 2978001 row(s) are porcessed.
# 2979001 row(s) are porcessed.
# 2980001 row(s) are porcessed.
# 2981001 row(s) are porcessed.
# 2982001 row(s) are porcessed.
# 2983001 row(s) are porcessed.
# 2984001 row(s) are porcessed.
# 2985001 row(s) are porcessed.
# 2986001 row(s) are porcessed.
# 2987001 row(s) are porcessed.
# 2988001 row(s) are porcessed.
# 2989001 row(s) are porcessed.
# 2990001 row(s) are porcessed.
# 2991001 row(s) are porcessed.
# 2992001 row(s) are porcessed.
# 2993001 row(s) are porcessed.
# 2994001 row(s) are porcessed.
# 2995001 row(s) are porcessed.
# 2996001 row(s) are porcessed.
# 2997001 row(s) are porcessed.
# 2998001 row(s) are porcessed.
# 2999001 row(s) are porcessed.
# 3000001 row(s) are porcessed.
# 3000887 rows are porcessed.
# Data preprocess is completed, and the result is saved to train_data.csv.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                int64
#  1   date              datetime64[ns]
#  2   store_nbr         int64
#  3   family            object
#  4   sales             float64
#  5   onpromotion       int64
#  6   city              object
#  7   state             object
#  8   type              object
#  9   cluster           int64
#  10  date_type         object
#  11  date_description  object
#  12  year              int64
#  13  month             int64
#  14  day               int64
#  15  weekday           object
#  16  dcoilwtico        float64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(7)
# memory usage: 389.2+ MB
# None
# temp_data.csv 파일이 삭제되었습니다.
# 1 row(s) are porcessed.
# 1001 row(s) are porcessed.
# 2001 row(s) are porcessed.
# 3001 row(s) are porcessed.
# 4001 row(s) are porcessed.
# 5001 row(s) are porcessed.
# 6001 row(s) are porcessed.
# 7001 row(s) are porcessed.
# 8001 row(s) are porcessed.
# 9001 row(s) are porcessed.
# 10001 row(s) are porcessed.
# 11001 row(s) are porcessed.
# 12001 row(s) are porcessed.
# 13001 row(s) are porcessed.
# 14001 row(s) are porcessed.
# 15001 row(s) are porcessed.
# 16001 row(s) are porcessed.
# 17001 row(s) are porcessed.
# 18001 row(s) are porcessed.
# 19001 row(s) are porcessed.
# 20001 row(s) are porcessed.
# 21001 row(s) are porcessed.
# 22001 row(s) are porcessed.
# 23001 row(s) are porcessed.
# 24001 row(s) are porcessed.
# 25001 row(s) are porcessed.
# 26001 row(s) are porcessed.
# 27001 row(s) are porcessed.
# 28001 row(s) are porcessed.
# 28511 rows are porcessed.
# Data preprocess is completed, and the result is saved to train_data.csv.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                28512 non-null  int64
#  1   date              28512 non-null  datetime64[ns]
#  2   store_nbr         28512 non-null  int64
#  3   family            28512 non-null  object
#  4   onpromotion       28512 non-null  int64
#  5   city              28512 non-null  object
#  6   state             28512 non-null  object
#  7   type              28512 non-null  object
#  8   cluster           28512 non-null  int64
#  9   date_type         28512 non-null  object
#  10  date_description  28512 non-null  object
#  11  year              28512 non-null  int64
#  12  month             28512 non-null  int64
#  13  day               28512 non-null  int64
#  14  weekday           28512 non-null  object
#  15  dcoilwtico        28512 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(7)
# memory usage: 3.5+ MB
# None
# temp_data.csv 파일이 삭제되었습니다.
# ((2945646, 16), (2945646,), (55242, 16), (55242,))

# %%
# train_w_val 데이터를 훈련 목적의 train_data (2017-07-16 이전)과 validation data (2017-07-16 ~ 08.15)로 분리
df_train_w_val = pd.read_csv('train_w_val.csv',parse_dates =['date'])
train_idx = pd.to_datetime(df_train_w_val['date']) < pd.to_datetime('2017-07-16')
val_idx = pd.to_datetime(df_train_w_val['date']) >= pd.to_datetime('2017-07-16')

# train, validation 및 test 데이터를 분리해서 dataframe에 저장
train_data = df_train_w_val[train_idx].drop('sales', axis=1)
train_target = df_train_w_val[train_idx]['sales']
val_data = df_train_w_val[val_idx].drop('sales', axis=1)
val_target = df_train_w_val[val_idx]['sales']
test_data = pd.read_csv('test.csv')

# 반복 모델 훈련 및 검증, 테스트를 위한 데이터를 /TestData 폴더에 csv 파일로 저장
train_data.to_csv('TestData/train_data.csv', index=False)
train_target.to_csv('TestData/train_target.csv', index=False)
val_data.to_csv('TestData/val_data.csv', index=False)
val_target.to_csv('TestData/val_target.csv', index=False)
test_data.to_csv('TestData/test_data.csv', index=False)

# %%
# 모델 별로 사용가능한 데이터를 One-Hot Encoding, StandardScale 및 Label Encoding을 적용하여, 별도 csv 파일로 저장장

# class type data
features = ['year', 'month', 'weekday','date_description', 'store_nbr','family', 'city', 'state', 'type', 'cluster']

# One-hot encoding 수행
train_data_oh = pd.get_dummies(train_data, columns=features)
val_data_oh = pd.get_dummies(val_data, columns=features)
test_data_oh = pd.get_dummies(test_data, columns=features)

# Numeric Data 표준화 (train data로 학습한 모델을 val & test 데이터에 적용)
train_data_oh_scaled, val_data_oh_scaled = scaler_function(train_data_oh, val_data_oh)
train_data_oh_scaled, test_data_oh_scaled = scaler_function(train_data_oh, test_data_oh)

train_data_oh_scaled.to_csv('TestData/train_data_oh_scaled.csv', index=False)
val_data_oh_scaled.to_csv('TestData/val_data_oh_scaled.csv', index=False)
test_data_oh_scaled.to_csv('TestData/test_data_oh_scaled.csv', index=False)

# label Encoding 수행 (Train data로 학습한 encoding을 val과 test에 적용)
train_data_label_encoded, val_data_label_encoded = label_encoding(train_data, val_data)
train_data_label_encoded, test_data_label_encoded = label_encoding(train_data, test_data)
train_data_label_encoded.to_csv('TestData/train_data_label_encoded.csv', index=False)
val_data_label_encoded.to_csv('TestData/val_data_label_encoded.csv', index=False)
test_data_label_encoded.to_csv('TestData/test_data_label_encoded.csv', index=False)
